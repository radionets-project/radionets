# %%
from IPython.display import Image

# %% [markdown]
# # Filter Deep Variations

# %% [markdown]
# In this chapter, the variations of `Filter Deep` are listed alongside with scripts and example evaluation plots.

# %% [markdown]
# ## Filter Deep with two channels

# %% [markdown]
# ### Variations

# %% [markdown]
# - 63 Pixels
#     - static and variable masks
#     - with and without data augmentation
# - 127 Pixels
# - 511 Pixels

# %% [markdown]
# Example training script in `.rc/training_filter_deep.toml`. The `MSE`-Loss was used as loss function.

# %% [markdown]
# ### Example evaluation plots

# %%
Image(data=".rc/filter_deep_eval/prediction_normal.png", width=800, height=500)

# %%
Image(data=".rc/filter_deep_eval/source_normal.png", width=800, height=500)

# %% [markdown]
# ## Filter Deep splitted in amplitude and phase

# %% [markdown]
# Instead of training a network with two channels, one can also divide a network into two seperate networks and train the amplitude and the phase seperately. This is explained here. The architecture still matches with the version before, only the activation functions differ. The `MSE`-Loss is still used as loss function, but is only evaluated on the amplitude or the phase, respectively. Example scripts are located in `.rc/training_filter_deep_amp.toml` and `.rc/training_filter_deep_phase.toml`.

# %% [markdown]
# ### Example evaluation plots

# %%
Image(data=".rc/filter_deep_eval/prediction_amp_phase.png", width=800, height=500)

# %%
Image(data=".rc/filter_deep_eval/source_amp_phase.png", width=800, height=500)
